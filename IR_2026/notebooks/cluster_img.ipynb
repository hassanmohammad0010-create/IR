# %% [markdown]
# # cluster charts

# %%
# !python scripts/cluster_visualize.py
# Out:
# ...
#   Cluster Scatter Visualization
# ...
#
# -----------------------------------------------------------------
#   Dataset: QUORA
# -----------------------------------------------------------------
#   Loading embedding index …
#   ✔ Embedding loaded  (4.80s)  docs=522,931  dim=384
#   Loading cluster index …
#   ✔ Cluster index loaded  (0.06s)  clusters=800
#
# -----------------------------------------------------------------
#   [QUORA] Generating scatter chart
# -----------------------------------------------------------------
#   ✔ Saved → cluster_scatter_quora.png  (0.46s)
#
# -----------------------------------------------------------------
#   Dataset: MSMARCO
# -----------------------------------------------------------------
#   Loading embedding index …
#   ✔ Embedding loaded  (2.17s)  docs=250,000  dim=384
#   Loading cluster index …
#   ✔ Cluster index loaded  (0.04s)  clusters=500
#
# -----------------------------------------------------------------
# ...
