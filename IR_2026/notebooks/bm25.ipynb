# %% [markdown]
# # BM25 model

# %%
# !python scripts/run_bm25.py --query_count 1
# Out:
# ...
#   BM25 Evaluation  |  query_count=1
# ...
#
# ...
#   Dataset: QUORA
# ...
#   Loading index from: C:\Users\Lenovo\Desktop\IR_Project\data\indexes\quora\bm25_index.pkl.gz
#   ✔ Index loaded  (3.95s)
#   ✔ Documents     : 522,931
#   ✔ Vocabulary    : 85,561
#
# -----------------------------------------------------------------
#   [QUORA] Evaluation across BM25 parameter presets
# -----------------------------------------------------------------
#
#   📊 [QUORA] Default (k1=1.2, b=0.75)
#      Queries evaluated : 1
#      Evaluation time   : 5.44s
#      MAP                 : 0.0786
#      P@10                : 0.2000
#      Recall@100          : 0.2133
#      nDCG@10             : 0.1488
#
#   📊 [QUORA] High k1  (k1=1.5, b=0.75)
#      Queries evaluated : 1
#      Evaluation time   : 3.82s
#      MAP                 : 0.0576
#      P@10                : 0.1000
#      Recall@100          : 0.2133
#      nDCG@10             : 0.0734
#
#   📊 [QUORA] Low b    (k1=1.2, b=0.50)
#      Queries evaluated : 1
# ...
